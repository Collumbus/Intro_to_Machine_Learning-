# %% [markdown]
# # Mini-Project

# %% [markdown]
# # Quiz: Warming Up with parseOutText()

# %%
#!/usr/bin/python

from nltk.stem.snowball import SnowballStemmer
import string

def parseOutText(f):
    """ given an opened email file f, parse out all text below the
        metadata block at the top
        (in Part 2, you will also add stemming capabilities)
        and return a string that contains all the words
        in the email (space-separated)

        example use case:
        f = open("email_file_name.txt", "r")
        text = parseOutText(f)

        """


    stemmer = SnowballStemmer("english")

    f.seek(0)  ### go back to beginning of file (annoying)
    all_text = f.read()

    ### split off metadata
    content = all_text.split("X-FileName:")
    words = ""
    if len(content) > 1:
        ### remove punctuation
        text_string = content[1].translate(string.maketrans("", ""), string.punctuation)

        ### project part 2: comment out the line below
        #words = text_string

        ### split the text string into individual words, stem each word,
        ### and append the stemmed word to words (make sure there's a single
        ### space between each stemmed word)
        email = text_string.split()
        for word in email:
            words += word + " "




    return words



def main():
    ff = open("../ud120-projects/text_learning/test_email.txt", "r")
    text = parseOutText(ff)
    print text



if __name__ == '__main__':
    main()
# Out:
# Hi Everyone If you can read this message youre properly using parseOutText Please proceed to the next part of the project

# %% [markdown]
# # Quiz: Deploying Stemming

# %%
#!/usr/bin/python

from nltk.stem.snowball import SnowballStemmer
import string

def parseOutText(f):
    """ given an opened email file f, parse out all text below the
        metadata block at the top
        (in Part 2, you will also add stemming capabilities)
        and return a string that contains all the words
        in the email (space-separated)

        example use case:
        f = open("email_file_name.txt", "r")
        text = parseOutText(f)

        """


    stemmer = SnowballStemmer("english")

    f.seek(0)  ### go back to beginning of file (annoying)
    all_text = f.read()

    ### split off metadata
    content = all_text.split("X-FileName:")
    words = ""
    if len(content) > 1:
        ### remove punctuation
        text_string = content[1].translate(string.maketrans("", ""), string.punctuation)

        ### project part 2: comment out the line below
        #words = text_string

        ### split the text string into individual words, stem each word,
        ### and append the stemmed word to words (make sure there's a single
        ### space between each stemmed word)
        email = text_string.split()
        for word in email:
            stword = stemmer.stem(word)
            words += stword + " "




    return words



def main():
    ff = open("../ud120-projects/text_learning/test_email.txt", "r")
    text = parseOutText(ff)
    print text



if __name__ == '__main__':
    main()
# Out:
# hi everyon if you can read this messag your proper use parseouttext pleas proceed to the next part of the project

# %% [markdown]
# # Quiz: Clean Away "Signature Words"

# %%
#!/usr/bin/python

import os
import pickle
import re
import sys

sys.path.append( "../ud120-projects/tools/" )
from parse_out_email_text import parseOutText

"""
    Starter code to process the emails from Sara and Chris to extract
    the features and get the documents ready for classification.

    The list of all the emails from Sara are in the from_sara list
    likewise for emails from Chris (from_chris)

    The actual documents are in the Enron email dataset, which
    you downloaded/unpacked in Part 0 of the first mini-project. If you have
    not obtained the Enron email corpus, run startup.py in the tools folder.

    The data is stored in lists and packed away in pickle files at the end.
"""


from_sara  = open("../ud120-projects/text_learning/from_sara.txt", "r")
from_chris = open("../ud120-projects/text_learning/from_chris.txt", "r")

from_data = []
word_data = []

### temp_counter is a way to speed up the development--there are
### thousands of emails from Sara and Chris, so running over all of them
### can take a long time
### temp_counter helps you only look at the first 200 emails in the list so you
### can iterate your modifications quicker
temp_counter = 0


for name, from_person in [("sara", from_sara), ("chris", from_chris)]:
    for path in from_person:
        ### only look at first 200 emails when developing
        ### once everything is working, remove this line to run over full dataset
        temp_counter += 1
        if temp_counter < 200:
            path = os.path.join('../ud120-projects', path[:-1])
            print path
            email = open(path, "r")

            ### use parseOutText to extract the text from the opened email
            parsed = parseOutText(email)

            ### use str.replace() to remove any instances of the words
            ### ["sara", "shackleton", "chris", "germani"]
            sw = ["sara", "shackleton", "chris", "germani"]
            for i in sw:
                parsed = parsed.replace(i,"")

            ### append the text to word_data
            word_data.append(parsed)

            ### append a 0 to from_data if email is from Sara, and 1 if email is from Chris
            if from_person == from_sara:
                from_data.append(0)
            elif from_person == from_chris:
                from_data.append(1)

            email.close()

print "emails processed"
print ("\nThe string in word_data[152] is: %s \n" % word_data[152])
from_sara.close()
from_chris.close()

pickle.dump( word_data, open("../ud120-projects/text_learning/your_word_data.pkl", "w") )
pickle.dump( from_data, open("../ud120-projects/text_learning/your_email_authors.pkl", "w") )
# Out:
# ../ud120-projects/maildir/bailey-s/deleted_items/101.
# ../ud120-projects/maildir/bailey-s/deleted_items/106.
# ../ud120-projects/maildir/bailey-s/deleted_items/132.
# ../ud120-projects/maildir/bailey-s/deleted_items/185.
# ../ud120-projects/maildir/bailey-s/deleted_items/186.
# ../ud120-projects/maildir/bailey-s/deleted_items/187.
# ../ud120-projects/maildir/bailey-s/deleted_items/193.
# ../ud120-projects/maildir/bailey-s/deleted_items/195.
# ../ud120-projects/maildir/bailey-s/deleted_items/214.
# ../ud120-projects/maildir/bailey-s/deleted_items/215.
# ../ud120-projects/maildir/bailey-s/deleted_items/233.
# ../ud120-projects/maildir/bailey-s/deleted_items/242.
# ../ud120-projects/maildir/bailey-s/deleted_items/243.
# ../ud120-projects/maildir/bailey-s/deleted_items/244.
# ../ud120-projects/maildir/bailey-s/deleted_items/246.
# ../ud120-projects/maildir/bailey-s/deleted_items/247.
# ../ud120-projects/maildir/bailey-s/deleted_items/254.
# ../ud120-projects/maildir/bailey-s/deleted_items/259.
# ../ud120-projects/maildir/bailey-s/deleted_items/260.
# ../ud120-projects/maildir/bailey-s/deleted_items/261.
# ../ud120-projects/maildir/bailey-s/deleted_items/263.
# ../ud120-projects/maildir/bailey-s/deleted_items/278.
# ../ud120-projects/maildir/bailey-s/deleted_items/290.
# ../ud120-projects/maildir/bailey-s/deleted_items/296.
# ../ud120-projects/maildir/bailey-s/deleted_items/302.
# ../ud120-projects/maildir/bailey-s/deleted_items/306.
# ../ud120-projects/maildir/bailey-s/deleted_items/307.
# ../ud120-projects/maildir/bailey-s/deleted_items/317.
# ../ud120-projects/maildir/bailey-s/deleted_items/320.
# ../ud120-projects/maildir/bailey-s/deleted_items/335.
# ../ud120-projects/maildir/bailey-s/deleted_items/70.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/1.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/16.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/17.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/2.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/24.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/26.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/27.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/33.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/35.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/36.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/4.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/52.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/73.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/8.
# ../ud120-projects/maildir/heard-m/brokerage_agreements/87.
# ../ud120-projects/maildir/heard-m/deleted_items/122.
# ../ud120-projects/maildir/heard-m/deleted_items/134.
# ../ud120-projects/maildir/heard-m/deleted_items/38.
# ../ud120-projects/maildir/heard-m/deleted_items/48.
# ../ud120-projects/maildir/heard-m/deleted_items/49.
# ../ud120-projects/maildir/heard-m/deleted_items/50.
# ../ud120-projects/maildir/heard-m/deleted_items/60.
# ../ud120-projects/maildir/heard-m/deleted_items/66.
# ../ud120-projects/maildir/heard-m/deleted_items/71.
# ../ud120-projects/maildir/heard-m/deleted_items/79.
# ../ud120-projects/maildir/heard-m/inbox/102.
# ../ud120-projects/maildir/heard-m/inbox/104.
# ../ud120-projects/maildir/heard-m/inbox/105.
# ../ud120-projects/maildir/heard-m/inbox/106.
# ../ud120-projects/maildir/heard-m/inbox/112.
# ../ud120-projects/maildir/heard-m/inbox/133.
# ../ud120-projects/maildir/heard-m/inbox/160.
# ../ud120-projects/maildir/heard-m/inbox/161.
# ../ud120-projects/maildir/heard-m/inbox/166.
# ../ud120-projects/maildir/heard-m/inbox/177.
# ../ud120-projects/maildir/heard-m/inbox/182.
# ../ud120-projects/maildir/heard-m/inbox/19.
# ../ud120-projects/maildir/heard-m/inbox/21.
# ../ud120-projects/maildir/heard-m/inbox/22.
# ../ud120-projects/maildir/heard-m/inbox/23.
# ../ud120-projects/maildir/heard-m/inbox/26.
# ../ud120-projects/maildir/heard-m/inbox/275.
# ../ud120-projects/maildir/heard-m/inbox/34.
# ../ud120-projects/maildir/heard-m/inbox/35.
# ../ud120-projects/maildir/heard-m/inbox/41.
# ../ud120-projects/maildir/heard-m/inbox/48.
# ../ud120-projects/maildir/heard-m/inbox/67.
# ../ud120-projects/maildir/heard-m/inbox/69.
# ../ud120-projects/maildir/heard-m/inbox/76.
# ../ud120-projects/maildir/hodge-j/deleted_items/206.
# ../ud120-projects/maildir/hodge-j/inbox/436.
# ../ud120-projects/maildir/jones-t/all_documents/10126.
# ../ud120-projects/maildir/jones-t/all_documents/10138.
# ../ud120-projects/maildir/jones-t/all_documents/10347.
# ../ud120-projects/maildir/jones-t/all_documents/10602.
# ../ud120-projects/maildir/jones-t/all_documents/10865.
# ../ud120-projects/maildir/jones-t/all_documents/10946.
# ../ud120-projects/maildir/jones-t/all_documents/11004.
# ../ud120-projects/maildir/jones-t/all_documents/11404.
# ../ud120-projects/maildir/jones-t/all_documents/11696.
# ../ud120-projects/maildir/jones-t/all_documents/11799.
# ../ud120-projects/maildir/jones-t/all_documents/12130.
# ../ud120-projects/maildir/jones-t/all_documents/12231.
# ../ud120-projects/maildir/jones-t/all_documents/1238.
# ../ud120-projects/maildir/jones-t/all_documents/1334.
# ../ud120-projects/maildir/jones-t/all_documents/1373.
# ../ud120-projects/maildir/jones-t/all_documents/1397.
# ../ud120-projects/maildir/jones-t/all_documents/1465.
# ../ud120-projects/maildir/jones-t/all_documents/1469.
# ../ud120-projects/maildir/jones-t/all_documents/1534.
# ../ud120-projects/maildir/jones-t/all_documents/1566.
# ../ud120-projects/maildir/jones-t/all_documents/1607.
# ../ud120-projects/maildir/jones-t/all_documents/1608.
# ../ud120-projects/maildir/jones-t/all_documents/1661.
# ../ud120-projects/maildir/jones-t/all_documents/1693.
# ../ud120-projects/maildir/jones-t/all_documents/1727.
# ../ud120-projects/maildir/jones-t/all_documents/1746.
# ../ud120-projects/maildir/jones-t/all_documents/1760.
# ../ud120-projects/maildir/jones-t/all_documents/1848.
# ../ud120-projects/maildir/jones-t/all_documents/1936.
# ../ud120-projects/maildir/jones-t/all_documents/1970.
# ../ud120-projects/maildir/jones-t/all_documents/1976.
# ../ud120-projects/maildir/jones-t/all_documents/2035.
# ../ud120-projects/maildir/jones-t/all_documents/2091.
# ../ud120-projects/maildir/jones-t/all_documents/2117.
# ../ud120-projects/maildir/jones-t/all_documents/2172.
# ../ud120-projects/maildir/jones-t/all_documents/2189.
# ../ud120-projects/maildir/jones-t/all_documents/2205.
# ../ud120-projects/maildir/jones-t/all_documents/2313.
# ../ud120-projects/maildir/jones-t/all_documents/2316.
# ../ud120-projects/maildir/jones-t/all_documents/2344.
# ../ud120-projects/maildir/jones-t/all_documents/2448.
# ../ud120-projects/maildir/jones-t/all_documents/2759.
# ../ud120-projects/maildir/jones-t/all_documents/2798.
# ../ud120-projects/maildir/jones-t/all_documents/2827.
# ../ud120-projects/maildir/jones-t/all_documents/2847.
# ../ud120-projects/maildir/jones-t/all_documents/2859.
# ../ud120-projects/maildir/jones-t/all_documents/2910.
# ../ud120-projects/maildir/jones-t/all_documents/2983.
# ../ud120-projects/maildir/jones-t/all_documents/3028.
# ../ud120-projects/maildir/jones-t/all_documents/3058.
# ../ud120-projects/maildir/jones-t/all_documents/3081.
# ../ud120-projects/maildir/jones-t/all_documents/3101.
# ../ud120-projects/maildir/jones-t/all_documents/3321.
# ../ud120-projects/maildir/jones-t/all_documents/3333.
# ../ud120-projects/maildir/jones-t/all_documents/3362.
# ../ud120-projects/maildir/jones-t/all_documents/3642.
# ../ud120-projects/maildir/jones-t/all_documents/3794.
# ../ud120-projects/maildir/jones-t/all_documents/3816.
# ../ud120-projects/maildir/jones-t/all_documents/3829.
# ../ud120-projects/maildir/jones-t/all_documents/3840.
# ../ud120-projects/maildir/jones-t/all_documents/3841.
# ../ud120-projects/maildir/jones-t/all_documents/3857.
# ../ud120-projects/maildir/jones-t/all_documents/3858.
# ../ud120-projects/maildir/jones-t/all_documents/3873.
# ../ud120-projects/maildir/jones-t/all_documents/3921.
# ../ud120-projects/maildir/jones-t/all_documents/3961.
# ../ud120-projects/maildir/jones-t/all_documents/3973.
# ../ud120-projects/maildir/jones-t/all_documents/3993.
# ../ud120-projects/maildir/jones-t/all_documents/3997.
# ../ud120-projects/maildir/jones-t/all_documents/4046.
# ../ud120-projects/maildir/jones-t/all_documents/4056.
# ../ud120-projects/maildir/jones-t/all_documents/4136.
# ../ud120-projects/maildir/jones-t/all_documents/4161.
# ../ud120-projects/maildir/jones-t/all_documents/4212.
# ../ud120-projects/maildir/jones-t/all_documents/4244.
# ../ud120-projects/maildir/jones-t/all_documents/4249.
# ../ud120-projects/maildir/jones-t/all_documents/4251.
# ../ud120-projects/maildir/jones-t/all_documents/4255.
# ../ud120-projects/maildir/jones-t/all_documents/4496.
# ../ud120-projects/maildir/jones-t/all_documents/4650.
# ../ud120-projects/maildir/jones-t/all_documents/4654.
# ../ud120-projects/maildir/jones-t/all_documents/4710.
# ../ud120-projects/maildir/jones-t/all_documents/4741.
# ../ud120-projects/maildir/jones-t/all_documents/4743.
# ../ud120-projects/maildir/jones-t/all_documents/4757.
# ../ud120-projects/maildir/jones-t/all_documents/4819.
# ../ud120-projects/maildir/jones-t/all_documents/4895.
# ../ud120-projects/maildir/jones-t/all_documents/4938.
# ../ud120-projects/maildir/jones-t/all_documents/4968.
# ../ud120-projects/maildir/jones-t/all_documents/5035.
# ../ud120-projects/maildir/jones-t/all_documents/5055.
# ../ud120-projects/maildir/jones-t/all_documents/5063.
# ../ud120-projects/maildir/jones-t/all_documents/5419.
# ../ud120-projects/maildir/jones-t/all_documents/5519.
# ../ud120-projects/maildir/jones-t/all_documents/5523.
# ../ud120-projects/maildir/jones-t/all_documents/5555.
# ../ud120-projects/maildir/jones-t/all_documents/5575.
# ../ud120-projects/maildir/jones-t/all_documents/5588.
# ../ud120-projects/maildir/jones-t/all_documents/5589.
# ../ud120-projects/maildir/jones-t/all_documents/5646.
# ../ud120-projects/maildir/jones-t/all_documents/5654.
# ../ud120-projects/maildir/jones-t/all_documents/5691.
# ../ud120-projects/maildir/jones-t/all_documents/5693.
# ../ud120-projects/maildir/jones-t/all_documents/5751.
# ../ud120-projects/maildir/jones-t/all_documents/5859.
# ../ud120-projects/maildir/jones-t/all_documents/5884.
# ../ud120-projects/maildir/jones-t/all_documents/5928.
# ../ud120-projects/maildir/jones-t/all_documents/5936.
# ../ud120-projects/maildir/jones-t/all_documents/5948.
# ../ud120-projects/maildir/jones-t/all_documents/9401.
# ../ud120-projects/maildir/jones-t/all_documents/9408.
# ../ud120-projects/maildir/jones-t/all_documents/9430.
# ../ud120-projects/maildir/jones-t/all_documents/9550.
# ../ud120-projects/maildir/jones-t/all_documents/9627.
# ../ud120-projects/maildir/jones-t/all_documents/9808.
# ../ud120-projects/maildir/jones-t/deleted_items/45.
# ../ud120-projects/maildir/jones-t/inbox/742.
# emails processed
#
# The string in word_data[152] is: tjonesnsf stephani and sam need nymex calendar

# %% [markdown]
# # Quiz: TfIdf It

# %%
#!/usr/bin/python

import os
import pickle
import re
import sys

sys.path.append( "../ud120-projects/tools/" )
from parse_out_email_text import parseOutText

"""
    Starter code to process the emails from Sara and Chris to extract
    the features and get the documents ready for classification.

    The list of all the emails from Sara are in the from_sara list
    likewise for emails from Chris (from_chris)

    The actual documents are in the Enron email dataset, which
    you downloaded/unpacked in Part 0 of the first mini-project. If you have
    not obtained the Enron email corpus, run startup.py in the tools folder.

    The data is stored in lists and packed away in pickle files at the end.
"""


from_sara  = open("../ud120-projects/text_learning/from_sara.txt", "r")
from_chris = open("../ud120-projects/text_learning/from_chris.txt", "r")

from_data = []
word_data = []

### temp_counter is a way to speed up the development--there are
### thousands of emails from Sara and Chris, so running over all of them
### can take a long time
### temp_counter helps you only look at the first 200 emails in the list so you
### can iterate your modifications quicker
temp_counter = 0


for name, from_person in [("sara", from_sara), ("chris", from_chris)]:
    for path in from_person:
        ### only look at first 200 emails when developing
        ### once everything is working, remove this line to run over full dataset
        temp_counter += 1
        #if temp_counter < 200:
        path = os.path.join('../ud120-projects', path[:-1])
        #print path
        email = open(path, "r")

        ### use parseOutText to extract the text from the opened email
        parsed = parseOutText(email)

        ### use str.replace() to remove any instances of the words
        ### ["sara", "shackleton", "chris", "germani"]
        sw = ["sara", "shackleton", "chris", "germani"]
        for i in sw:
            parsed = parsed.replace(i,"")

        ### append the text to word_data
        word_data.append(parsed)

        ### append a 0 to from_data if email is from Sara, and 1 if email is from Chris
        if from_person == from_sara:
            from_data.append(0)
        elif from_person == from_chris:
            from_data.append(1)

        email.close()

print "emails processed"
print ("\nThe string in word_data[152] is: %s \n" % word_data[152])
from_sara.close()
from_chris.close()

pickle.dump( word_data, open("../ud120-projects/text_learning/your_word_data.pkl", "w") )
pickle.dump( from_data, open("../ud120-projects/text_learning/your_email_authors.pkl", "w") )
# Out:
# emails processed
#
# The string in word_data[152] is: tjonesnsf stephani and sam need nymex calendar

# %%
### in Part 4, do TfIdf vectorization here

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words="english")
X = vectorizer.fit_transform(word_data)
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(X)

vector = vectorizer.get_feature_names()

# How many unique words are there in your Tfldf?
print ('There are %i unique words in TfIdf.'% len(vector))
# Out:
# There are 38757 unique words in TfIdf.

# %% [markdown]
# # Quiz: Accessing TfIdf Features

# %%
print ('The word in position 34597 is "%s".'% vector[34597])
# Out:
# The word in position 34597 is "stephaniethank".
